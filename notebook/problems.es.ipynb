# %% [markdown]
# # Problemas de Estadística Descriptiva
#
# ## Ejercicio 1 – ¿Qué tan largos son los títulos de las películas?
#
# En este ejercicio vas a aplicar técnicas de estadística descriptiva sobre un conjunto de datos real: una base con 1000 películas populares del sitio IMDb.
#
# A partir del título de cada película, vas a:
# - Calcular la longitud del título (en caracteres).
# - Obtener métricas estadísticas clave: media, mediana, moda, rango, varianza, desviación estándar, asimetría y curtosis.
# - Identificar los títulos más largos y más cortos.
# - Visualizar la distribución de estas longitudes con un histograma y una curva de densidad.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import skew, kurtosis, mode


url = "../assets/imdb_1000.csv"
df = pd.read_csv(url)
df
# Out:
#      star_rating                                            title  \
# 0            9.3                         The Shawshank Redemption
# 1            9.2                                    The Godfather
# 2            9.1                           The Godfather: Part II
# 3            9.0                                  The Dark Knight
# 4            8.9                                     Pulp Fiction
# ..           ...                                              ...
# 974          7.4                                          Tootsie
# 975          7.4                      Back to the Future Part III
# 976          7.4  Master and Commander: The Far Side of the World
# 977          7.4                                      Poltergeist
# 978          7.4                                      Wall Street
#
#     content_rating      genre  duration  \
# 0                R      Crime       142
# 1                R      Crime       175
# 2                R      Crime       200
# ...

# %%
df['title_length'] = df['title'].str.len()

df["title_length"].head()
# Out:
# 0    24
# 1    13
# 2    22
# 3    15
# 4    12
# Name: title_length, dtype: int64

# %%
mean = np.mean(df["title_length"])
mediana = np.median(df["title_length"])
moda = mode(df["title_length"], keepdims=True).mode[0]


f'El Mean es: {mean}, La Mediana: {mediana}, y La Moda: {moda}'
# Out:
# 'El Mean es: 15.481103166496425, La Mediana: 14.0, y La Moda: 12'

# %%
rango = df['title_length'].max() - df['title_length'].min()
varianza = (df['title_length'].var())
desviación_estandar = (df ['title_length'].std())

f'El Rango: {rango}, La Varianza: {varianza}, y La Desviación estandar: {desviación_estandar}'
# Out:
# 'El Rango: 67, La Varianza: 72.1067488840288, y La Desviación estandar: 8.491569282766807'

# %%
asimetria = df['title_length'].skew()
curtosis = df['title_length'].kurt()


f'La Asimetria: {asimetria}, y La Curtosis: {curtosis}'
# Out:
# 'La Asimetria: 1.5252523464631278, y La Curtosis: 3.8122887061291544'

# %%
titulo_mas_corto = df.loc[df['title_length'].idxmin(), 'title']
longitud_mas_corta = df['title_length'].min()

titulo_mas_largo = df.loc[df['title_length'].idxmax(), 'title']
longitud_mas_larga = df['title_length'].max()

print(f"Título más corto: '{titulo_mas_corto}' - Longitud: {longitud_mas_corta} caracteres")
print(f"Título más largo: '{titulo_mas_largo}' - Longitud: {longitud_mas_larga} caracteres")
# Out:
# Título más corto: 'M' - Longitud: 1 caracteres
# Título más largo: 'Dr. Strangelove or: How I Learned to Stop Worrying and Love the Bomb' - Longitud: 68 caracteres

# %%
df['title_length'].hist(bins = 'sqrt')

plt.title("Titulos de Peliculas")
plt.xlabel('Frecuencia')
plt.ylabel('Longitud de los Titulos')
plt.show()

# %% [markdown]
# ---
#
# ## Ejercicio 2 – Cálculo manual de desviación estándar
#
# En este ejercicio vas a calcular manualmente la desviación estándar, seleccionando cinco títulos reales del dataset de películas que cargaste antes.

# %%
data = [10, 13, 14, 18, 22]

# %%
suma = 0

for valores in data:
    suma += valores

media = suma/len(data)
media
# Out:
# 15.4

# %%
diferencia_al_cuadrado = 0

for valores in data:
    diferencia_al_cuadrado +=(valores - media) ** 2
f"suma de diferencias al cuadrado {diferencia_al_cuadrado}"
# Out:
# 'suma de diferencias al cuadrado 87.19999999999999'

# %%
varianza = diferencia_al_cuadrado/len(data)
desviacion_manual = varianza ** 0.5

print(f"Varianza: {varianza}")
print(f"Desviación estándar: {desviacion_manual}")
# Out:
# Varianza: 17.439999999999998
# Desviación estándar: 4.176122603564219
